# %% [markdown]
# <a href="https://colab.research.google.com/github/uvinduuu/EMLEC-24/blob/main/HS1_Part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Terminology**
#
#
# 1.   Neural Network
# 2.   Parametric Model
# 3.   Weight Initialization
# 4.   Dataset
# 5.   Optimizer: Optmizer, Loss Function
# 6.   Model Compilation
# 7.   Training
# 8.   Inference (Predict)

# %% [markdown]
# # Example 1: Simple regression model

# %%
from tensorflow import keras
import matplotlib.pyplot as plt

# %% [markdown]
# # examples: [(-2, -8), (-1, -5), (0, -2), (1, 1), (2, 4), (3, 7)]

# %%
X = [-2, -1, 0, 1, 2, 3]  #  Features

# %%
Y = [-8, -5, -2, 1, 4, 7]  # Labels

# %% [markdown]
# # By looking at the numbers, we can say that the,
#
# # Relationship is Y = 3X - 2

# %%
plt.plot(X, Y)

# %%
def f(x):
    return 3*x - 2

y = f(x = 10)
print('y = ', y)
# Out:
# y =  28

# %% [markdown]
# ## Simplest Possible Neural Network

# %%
model = keras.Sequential([keras.layers.Dense(units = 1, input_shape = [1])])

# %% [markdown]
#  One neuron as one input, dense is similar to a neruron layer, units = no of neurons, shape means how many input parameters in the input

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 1)                 2
#
# ...
# Total params: 2 (8.00 Byte)
# Trainable params: 2 (8.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer = keras.optimizers.SGD(learning_rate=0.01), loss = 'mean_squared_error')

# %% [markdown]
# # Before Training

# %%
print(model.predict([-2.0]))
# Out:
# 1/1 [==============================] - 0s 36ms/step
# [[1.4216208]]

# %%
w, b = model.get_weights()
print(f'Before Training... \n weight = {w} \n bias = {b}')
# Out:
# Before Training...
#  weight = [[-0.7108104]]
#  bias = [0.]

# %%
-2.0 * w + b
# Out:
# array([[1.4216208]], dtype=float32)

# %%
hist = model.fit(X, Y, epochs = 500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 427ms/step - loss: 40.1837
# Epoch 2/500
# 1/1 [==============================] - 0s 10ms/step - loss: 35.7054
# Epoch 3/500
# 1/1 [==============================] - 0s 9ms/step - loss: 31.7731
# Epoch 4/500
# 1/1 [==============================] - 0s 9ms/step - loss: 28.3183
# Epoch 5/500
# 1/1 [==============================] - 0s 9ms/step - loss: 25.2812
# Epoch 6/500
# 1/1 [==============================] - 0s 10ms/step - loss: 22.6096
# Epoch 7/500
# 1/1 [==============================] - 0s 10ms/step - loss: 20.2578
# Epoch 8/500
# 1/1 [==============================] - 0s 11ms/step - loss: 18.1860
# Epoch 9/500
# 1/1 [==============================] - 0s 11ms/step - loss: 16.3594
# Epoch 10/500
# 1/1 [==============================] - 0s 11ms/step - loss: 14.7474
# Epoch 11/500
# 1/1 [==============================] - 0s 12ms/step - loss: 13.3234
# Epoch 12/500
# ...

# %%
plt.title('Training ' + 'loss')
plt.plot(hist.history['loss'])
plt.show()

# %%
y = f(x = 10)
print(f'Expected Output = {y}')
# Out:
# Expected Output = 28

# %%
pred = model.predict([10.0])

print(f'Actual Output = {pred[0][0]}')
# Out:
# 1/1 [==============================] - 0s 37ms/step
# Actual Output = 27.999595642089844

# %%
w, b = model.get_weights()
print(f'After Training.. \n weight = {w} \n bias = {b}')
# Out:
# After Training..
#  weight = [[2.9999259]]
#  bias = [-1.9996622]
